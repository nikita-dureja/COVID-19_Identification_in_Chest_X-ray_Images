# %%
import re
import pandas as pd
import ntpath

# %%
image_names = {"non-infection":list(), "covid-19 pneumonia":list(),"non-covid-19 pneumonia":list()}

# %% [markdown]
# ### COVID-19 RADIOGRAPHY DATABASE

# %%
normal = pd.read_excel("NORMAL.metadata.xlsx").assign(label="non-infection")
covid19 = pd.read_excel("COVID-19.metadata.xlsx").assign(label="covid-19 pneumonia")
pneumonia = pd.read_excel("Viral Pneumonia.matadata.xlsx").assign(label="non-covid-19 pneumonia")

radiography = pd.concat([normal, covid19, pneumonia]).rename(columns={"URL":"url"})
def process_filename(filename):
    return re.sub(r"-(\d+)$", r" (\1)", filename)+'.png'
df = radiography.assign(dataset="Radiography",
                        view="AP",
                        filename=radiography["FILE NAME"].apply(process_filename))[["filename","url", "label","dataset", "view"]]

# %% [markdown]
# ### covid-chestxray-dataset
# X-ray and CT images of patients which are positive or suspected of COVID-19 or other viral and bacterial pneumonias (MERS, SARS, and ARDS.)

# %%
chest = pd.read_csv("covid_chestxray_metadata.csv")
chest.columns
# Out:
# Index(['patientid', 'offset', 'sex', 'age', 'finding', 'RT_PCR_positive',
#        'survival', 'intubated', 'intubation_present', 'went_icu', 'in_icu',
#        'needed_supplemental_O2', 'extubated', 'temperature', 'pO2_saturation',
#        'leukocyte_count', 'neutrophil_count', 'lymphocyte_count', 'view',
#        'modality', 'date', 'location', 'folder', 'filename', 'doi', 'url',
#        'license', 'clinical_notes', 'other_notes'],
#       dtype='object')

# %%
def convert_finding_to_label(finding):
    if "COVID-19" in finding:
        return "covid-19 pneumonia"
    return "non-covid-19 pneumonia"

chest= chest.assign(label=chest.finding.apply(convert_finding_to_label), dataset="covid_chestxray")

# %%
df = pd.concat([df, chest[["filename","url", "label", "dataset", "view"]]])
df
# Out:
#                                       filename  \
# 0                               NORMAL (1).png
# 1                               NORMAL (2).png
# 2                               NORMAL (3).png
# 3                               NORMAL (4).png
# 4                               NORMAL (5).png
# ..                                         ...
# 925   e0e3a6526a3fecadfca2be13242798_jumbo.jpg
# 926  2264f643b18b1010ec10a850f17550_jumbo.jpeg
# 927  800f798a58d0cbcc72eb234f192461_jumbo.jpeg
# 928   55f5189d2c23688ac8dc1d58eb65cf_jumbo.jpg
# 929   d2cdf41a662113279d2ec21af3a4e2_jumbo.jpg
#
#                                                    url  \
# 0    https://www.kaggle.com/paultimothymooney/chest...
# 1    https://www.kaggle.com/paultimothymooney/chest...
# 2    https://www.kaggle.com/paultimothymooney/chest...
# 3    https://www.kaggle.com/paultimothymooney/chest...
# 4    https://www.kaggle.com/paultimothymooney/chest...
# ..                                                 ...
# 925  https://radiopaedia.org/cases/left-lower-lobe-...
# 926  https://radiopaedia.org/cases/silhouette-sign-...
# 927  https://radiopaedia.org/cases/silhouette-sign-...
# 928  https://radiopaedia.org/cases/left-lower-lobe-...
# 929  https://radiopaedia.org/cases/left-lower-lobe-...
#
#                       label          dataset view
# 0             non-infection      Radiography   AP
# 1             non-infection      Radiography   AP
# 2             non-infection      Radiography   AP
# 3             non-infection      Radiography   AP
# 4             non-infection      Radiography   AP
# ..                      ...              ...  ...
# 925  non-covid-19 pneumonia  covid_chestxray    L
# 926  non-covid-19 pneumonia  covid_chestxray   PA
# 927  non-covid-19 pneumonia  covid_chestxray    L
# 928  non-covid-19 pneumonia  covid_chestxray   PA
# 929  non-covid-19 pneumonia  covid_chestxray    L
#
# [3835 rows x 5 columns]

# %% [markdown]
# ### Figure1-COVID-chestxray-dataset

# %%
def convert_figure1_finding(finding):
    if finding == "No finding":
        return "non-infection"
    elif finding == "COVID-19":
        return "covid-19 pneumonia"
    elif finding == "Pneumonia":
        return "non-covid-19 pneumonia"

# %%
import os
def find_extension(filename):
    path = os.path.join("..", "datasets","figure1","images", filename)
    png = path+'.png'
    jpg = path+'.jpg'
    if os.path.isfile(png):
        return png
    elif os.path.isfile(jpg):
        return jpg

# %%
figure1 = pd.read_csv("figure1_covid_chestxray_metadata.csv", encoding='iso-8859-1')
figure1 = figure1.assign(url='', dataset="figure1",
                         filename=figure1.patientid.apply(find_extension),
                         label=figure1.finding.apply(convert_figure1_finding)).dropna(subset=["label"])

# figure1

# %%
df = pd.concat([df, figure1[["filename", "url","label", "dataset", "view"]]])
df
# Out:
#                                        filename  \
# 0                                NORMAL (1).png
# 1                                NORMAL (2).png
# 2                                NORMAL (3).png
# 3                                NORMAL (4).png
# 4                                NORMAL (5).png
# ..                                          ...
# 48  ..\datasets\figure1\images\COVID-00043a.jpg
# 49  ..\datasets\figure1\images\COVID-00043b.jpg
# 51   ..\datasets\figure1\images\COVID-00045.png
# 52   ..\datasets\figure1\images\COVID-00046.png
# 54   ..\datasets\figure1\images\COVID-00048.png
#
#                                                   url               label  \
# 0   https://www.kaggle.com/paultimothymooney/chest...       non-infection
# 1   https://www.kaggle.com/paultimothymooney/chest...       non-infection
# 2   https://www.kaggle.com/paultimothymooney/chest...       non-infection
# 3   https://www.kaggle.com/paultimothymooney/chest...       non-infection
# 4   https://www.kaggle.com/paultimothymooney/chest...       non-infection
# ..                                                ...                 ...
# 48                                                     covid-19 pneumonia
# 49                                                     covid-19 pneumonia
# 51                                                     covid-19 pneumonia
# 52                                                     covid-19 pneumonia
# 54                                                     covid-19 pneumonia
#
#         dataset view
# 0   Radiography   AP
# 1   Radiography   AP
# 2   Radiography   AP
# 3   Radiography   AP
# 4   Radiography   AP
# ..          ...  ...
# 48      figure1  NaN
# 49      figure1  NaN
# 51      figure1  NaN
# 52      figure1  NaN
# 54      figure1   AP
#
# [3875 rows x 5 columns]

# %% [markdown]
# ###  Actualmed-COVID-chestxray-dataset

# %%
actual_med = pd.read_csv("actualmed_covid_chestxray_metadata.csv")

# %%
actual_med = actual_med.rename(columns={"imagename":"filename"}).assign(label=actual_med.finding.apply(convert_figure1_finding), url='', dataset='actualmed')
actual_med = actual_med[["filename", "label", "url", "dataset", "view"]].dropna(subset=["label"]).drop_duplicates(subset=["filename"])
df =pd.concat([actual_med, df])

# %%
def process_view(x):
    if type(x) == str:
        return x.upper()
    return None
df = df.assign(view=df.view.apply(process_view))

# %%
kaggle = df[df.url=="https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia"]
non_url = df[df.url=='']
non_kaggle = df[df.url!='https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia']

# %% [markdown]
# ## merge the datasets

# %%
merged = pd.concat([non_kaggle.drop_duplicates(subset=['url']), kaggle, non_url])
merged = merged.assign(imagename=merged.filename.apply(ntpath.basename)).drop("filename", axis=1).drop_duplicates()
merged.index = pd.RangeIndex(len(merged))
merged
# Out:
#                    label                                                url  \
# 0          non-infection
# 1     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# 2     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# 3     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# 4     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# ...                  ...                                                ...
# 3281  covid-19 pneumonia
# 3282  covid-19 pneumonia
# 3283  covid-19 pneumonia
# 3284  covid-19 pneumonia
# 3285  covid-19 pneumonia
#
#           dataset  view                                          imagename
# 0       actualmed    PA  CR.1.2.840.113564.1722810170.20200317090830828...
# 1     Radiography    AP                                    COVID-19(1).png
# 2     Radiography    AP                                    COVID-19(2).png
# 3     Radiography    AP                                    COVID-19(6).png
# 4     Radiography    AP                                    COVID-19(8).png
# ...           ...   ...                                                ...
# 3281      figure1  None                                   COVID-00043a.jpg
# 3282      figure1  None                                   COVID-00043b.jpg
# 3283      figure1  None                                    COVID-00045.png
# 3284      figure1  None                                    COVID-00046.png
# 3285      figure1    AP                                    COVID-00048.png
#
# [3286 rows x 5 columns]

# %%
merged = merged.assign(filename=merged.dataset.astype(str)+'/'+merged.imagename.astype(str))
merged
# Out:
#                    label                                                url  \
# 0          non-infection
# 1     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# 2     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# 3     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# 4     covid-19 pneumonia  https://www.sciencedirect.com/science/article/...
# ...                  ...                                                ...
# 3281  covid-19 pneumonia
# 3282  covid-19 pneumonia
# 3283  covid-19 pneumonia
# 3284  covid-19 pneumonia
# 3285  covid-19 pneumonia
#
#           dataset  view                                          imagename  \
# 0       actualmed    PA  CR.1.2.840.113564.1722810170.20200317090830828...
# 1     Radiography    AP                                    COVID-19(1).png
# 2     Radiography    AP                                    COVID-19(2).png
# 3     Radiography    AP                                    COVID-19(6).png
# 4     Radiography    AP                                    COVID-19(8).png
# ...           ...   ...                                                ...
# 3281      figure1  None                                   COVID-00043a.jpg
# 3282      figure1  None                                   COVID-00043b.jpg
# 3283      figure1  None                                    COVID-00045.png
# 3284      figure1  None                                    COVID-00046.png
# 3285      figure1    AP                                    COVID-00048.png
#
#                                                filename
# 0     actualmed/CR.1.2.840.113564.1722810170.2020031...
# 1                           Radiography/COVID-19(1).png
# 2                           Radiography/COVID-19(2).png
# 3                           Radiography/COVID-19(6).png
# 4                           Radiography/COVID-19(8).png
# ...                                                 ...
# 3281                           figure1/COVID-00043a.jpg
# 3282                           figure1/COVID-00043b.jpg
# 3283                            figure1/COVID-00045.png
# 3284                            figure1/COVID-00046.png
# 3285                            figure1/COVID-00048.png
#
# [3286 rows x 6 columns]

# %%
merged = merged[["filename", "imagename","label","view"]]
merged
# Out:
#                                                filename  \
# 0     actualmed/CR.1.2.840.113564.1722810170.2020031...
# 1                           Radiography/COVID-19(1).png
# 2                           Radiography/COVID-19(2).png
# 3                           Radiography/COVID-19(6).png
# 4                           Radiography/COVID-19(8).png
# ...                                                 ...
# 3281                           figure1/COVID-00043a.jpg
# 3282                           figure1/COVID-00043b.jpg
# 3283                            figure1/COVID-00045.png
# 3284                            figure1/COVID-00046.png
# 3285                            figure1/COVID-00048.png
#
#                                               imagename               label  \
# 0     CR.1.2.840.113564.1722810170.20200317090830828...       non-infection
# 1                                       COVID-19(1).png  covid-19 pneumonia
# 2                                       COVID-19(2).png  covid-19 pneumonia
# 3                                       COVID-19(6).png  covid-19 pneumonia
# 4                                       COVID-19(8).png  covid-19 pneumonia
# ...                                                 ...                 ...
# 3281                                   COVID-00043a.jpg  covid-19 pneumonia
# 3282                                   COVID-00043b.jpg  covid-19 pneumonia
# 3283                                    COVID-00045.png  covid-19 pneumonia
# 3284                                    COVID-00046.png  covid-19 pneumonia
# 3285                                    COVID-00048.png  covid-19 pneumonia
#
#       view
# 0       PA
# 1       AP
# 2       AP
# 3       AP
# 4       AP
# ...    ...
# 3281  None
# 3282  None
# 3283  None
# 3284  None
# 3285    AP
#
# [3286 rows x 4 columns]

# %%
merged.to_csv("merged_dataset.csv", index=None)
